# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import csv    
import gzip
from IPython.core.pylabtools import figsize
from IPython.display import clear_output
figsize(8, 8)
import re
import time
import os
import glob
# %matplotlib inline               
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
plt.style.use('ggplot')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
''' UNZIPPING MAIN FILE AND ITS CONTENTS '''

import tarfile

filename = os.path.join('/content/drive/My Drive/SMNI_CMI_TRAIN.tar.gz')
tar = tarfile.open(filename)
tar.extractall(path='/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped')
tar.close()

# %%
'''NAMING THE LOCATIONS'''

main_dir = "/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/"
eeg_data = os.path.join(main_dir+'SMNI_CMI_TRAIN/')  # unzipped subjects data file location

subject_files = os.listdir(eeg_data) # list all the subject folders

# %%
print(subject_files)
# Out:
# ['co2a0000364', 'co2a0000365', 'co2a0000368', 'co2a0000369', 'co2a0000370', 'co2a0000371', 'co2a0000372', 'co2a0000375', 'co2c0000338', 'co2a0000377', 'co2a0000378', 'co2c0000337', 'co2c0000339', 'co2c0000340', 'co2c0000341', 'co2c0000342', 'co2c0000344', 'co2c0000345', 'co2c0000346', 'co2c0000347', 'README']

# %% [markdown]
# ## Parse Data
#
# The following function will extract relevant parameters from each of the trial files belonging to the subject. The extracted files are stored in .csv format.

# %%
def extract_info(filename):
    """ Function to parse individual trial details for a subject.
        Args:
        filename - The name of file to be parsed
        
        Return:
        subject_id - The subject ID of the subject
        alcoholic - Return True for alcoholic subject
        stimulus  - Returns the stimulus for a particular trial
        trial_num - Trial number of the subject. On average there is 90 trial files per 
                    subject"""

    with gzip.open(filename, 'rt') as f:
        reader = csv.reader(f)
        for idx, row in enumerate(reader):
            if idx == 0:
                m = re.match('# (co\d(a|c)\d\d\d\d\d\d\d)', row[0])  #match pattern for the subject name
                                                                     #contains 'a' for alcoholics 
                                                                     #and 'c' for control
                subject_id = m.group(1)
                alcoholic = (m.group(2) == 'a')
            if idx == 3:
                m = re.match('# (.*?) trial (\d+)', row[0] + row[1]) #matching trial number 
                stimulus = re.sub('\W', ' ', m.group(1))
                trial_num = int(m.group(2))
#             if idx == 4:
#                 m = re.match('# (.*?) chan (\d+)', row[0])
#                 chan_name = re.sub('\W', '', m.group(1))
#                 chan_no = int(m.group(2))
    return subject_id, alcoholic, stimulus,trial_num

# %%
''' Converts files into CSV'''

def create_csv(subject_folder, main_dir, verbosity):
    """
        This function reads in individual trial files of subject folder, stacks the data
        in the form of a dataframe object and writes them out as CSV files.
        
        Args:
        subject_folder: The folder containing all the unzipped trial files of a subject
        main_dir: The main directory path to the data location
        verbosity: Pass a number greater than 1 for more output details
        
        Return:
        None 
    """
    data_dir = main_dir + subject_folder
    print('##########################################################')
    print('Beginning extraction of subject ', str(subject_folder))
    trial_dir = os.listdir(data_dir)
    trial_files = [file_i for file_i in trial_dir if file_i.endswith('.gz')]
    print('There are ', len(trial_files), 'trials under this subject')
    for file_no, file in enumerate(trial_files):
        tic = time.time()
        filename = data_dir + file
        df = pd.DataFrame()
        if verbosity == 0:
            print('Beginning extraction from file ', filename)

        sub_id, whether_alc, what_stimulus, trial_no = extract_info(filename)
        if verbosity > 1:
            print('Beginning extraction of file: ', filename)
            print('Subject id:', sub_id, ' Trial No: ', trial_no)
        with gzip.open(filename, 'rt') as f:
            reader = csv.reader(f, delimiter=' ')
            for idx, row in enumerate(reader):
                if row[0] != '#':
                    df = df.append(pd.DataFrame([row],columns=list(['trial_num', 'chan_name', 'epoch','voltage'])))
                        
                
            df = pd.concat([df,pd.DataFrame(columns=['subject_id', 'stimulus', 'alcoholic'])],
                           ignore_index=True)
            df[['subject_id', 'stimulus','alcoholic']] = [sub_id, what_stimulus, whether_alc] 
                
            out_name = main_dir + 'SMNI_CMI_TRAIN/' + sub_id + '_' + str(
                    trial_no) + '.csv'
            df.to_csv(out_name, index=False, sep='\t', encoding='utf-8')
            toc = time.time()
            
            if verbosity == 0:
                print('CSV file saved as ', out_name)
            elif verbosity > 1:
                print('There are ', df.shape[0], ' rows and ', df.shape[1],
                        ' columns in this dataframe object')
                print('CSV file successully saved as ', out_name)
                print('It will take %f mins more for this subject!' %
                        round(((len(trial_files) - float(file_no+1)) * float((toc - tic) / 60.0)),2))
                print('-------------------------------------------------------------------------------')
    print('All files extracted and saved.')
    print('###########################################################')
    return None

# %% [markdown]
# Start extraction of files for each subject. The extracted files will saved as csv files in the disk.
# The code proceeds only if files are missing. If all the files are satisfied the code prints the information with the number of trial files per subject.
# ### NOTE: Subject co2c0000367 has error flags in the trial files and hence is avoided from the study.
#
# ### IMP: DO NOT RUN THIS CELL IF YOU DON'T WANT TO PARSE THE DATA(OR IF YOU DON'T HAVE THE FOLDER WITH ALL THE PARSED FILE IN THE DISK).
# THIS WILL TAKE A LONG TIME TO EXECUTE.

# %%
len_trialfiles = []
for folder in subject_files:
    if(folder[0]!='c'):
      continue
    os.chdir(eeg_data+folder)
    zipped_files = [zipfile for zipfile in glob.glob(folder+'*.gz')]
    os.chdir(main_dir+'SMNI_CMI_TRAIN/')
    files = [file for file in glob.glob(folder+'*.csv')]
    len_trialfiles.append(len(zipped_files))
    ## check if all files are already extracted or not.
    if len(files) < len(zipped_files):
        create_csv("SMNI_CMI_TRAIN/"+folder+"/", main_dir, verbosity=5)
    else:
        print('All files satisfied for subject',folder,'; There are',len(files),'files.')
# Out:
# ##########################################################
# Beginning extraction of subject  SMNI_CMI_TRAIN/co2a0000364/
# There are  30 trials under this subject
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.002.gz
# Subject id: co2a0000364  Trial No:  2
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_2.csv
# It will take 12.180000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.000.gz
# Subject id: co2a0000364  Trial No:  0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_0.csv
# It will take 11.640000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.015.gz
# Subject id: co2a0000364  Trial No:  15
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_15.csv
# It will take 11.860000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.019.gz
# Subject id: co2a0000364  Trial No:  19
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_19.csv
# It will take 11.310000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.012.gz
# Subject id: co2a0000364  Trial No:  12
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_12.csv
# It will take 11.150000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.028.gz
# Subject id: co2a0000364  Trial No:  28
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_28.csv
# It will take 10.460000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.007.gz
# Subject id: co2a0000364  Trial No:  7
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_7.csv
# It will take 9.880000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.024.gz
# Subject id: co2a0000364  Trial No:  24
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_24.csv
# It will take 9.750000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.010.gz
# Subject id: co2a0000364  Trial No:  10
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_10.csv
# It will take 9.830000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.014.gz
# Subject id: co2a0000364  Trial No:  14
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_14.csv
# It will take 8.680000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.022.gz
# Subject id: co2a0000364  Trial No:  22
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_22.csv
# It will take 8.630000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.020.gz
# Subject id: co2a0000364  Trial No:  20
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_20.csv
# It will take 7.910000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.018.gz
# Subject id: co2a0000364  Trial No:  18
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_18.csv
# It will take 7.650000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.031.gz
# Subject id: co2a0000364  Trial No:  31
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_31.csv
# It will take 7.320000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.039.gz
# Subject id: co2a0000364  Trial No:  39
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_39.csv
# It will take 6.620000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.045.gz
# Subject id: co2a0000364  Trial No:  45
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_45.csv
# It will take 6.200000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.059.gz
# Subject id: co2a0000364  Trial No:  59
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_59.csv
# It will take 5.750000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.057.gz
# Subject id: co2a0000364  Trial No:  57
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_57.csv
# It will take 5.240000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.049.gz
# Subject id: co2a0000364  Trial No:  49
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_49.csv
# It will take 4.860000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.043.gz
# Subject id: co2a0000364  Trial No:  43
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_43.csv
# It will take 4.480000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.037.gz
# Subject id: co2a0000364  Trial No:  37
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_37.csv
# It will take 3.910000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.017.gz
# Subject id: co2a0000364  Trial No:  17
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_17.csv
# It will take 3.480000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.047.gz
# Subject id: co2a0000364  Trial No:  47
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_47.csv
# It will take 3.040000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.027.gz
# Subject id: co2a0000364  Trial No:  27
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_27.csv
# It will take 2.590000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.009.gz
# Subject id: co2a0000364  Trial No:  9
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_9.csv
# It will take 2.080000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.061.gz
# Subject id: co2a0000364  Trial No:  61
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_61.csv
# It will take 1.780000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.055.gz
# Subject id: co2a0000364  Trial No:  55
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_55.csv
# It will take 1.330000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.023.gz
# Subject id: co2a0000364  Trial No:  23
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_23.csv
# It will take 0.880000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.041.gz
# Subject id: co2a0000364  Trial No:  41
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_41.csv
# It will take 0.440000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.025.gz
# Subject id: co2a0000364  Trial No:  25
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_25.csv
# It will take 0.000000 mins more for this subject!
# -------------------------------------------------------------------------------
# All files extracted and saved.
# ###########################################################
# ##########################################################
# Beginning extraction of subject  SMNI_CMI_TRAIN/co2a0000365/
# There are  30 trials under this subject
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.006.gz
# Subject id: co2a0000365  Trial No:  6
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_6.csv
# It will take 12.160000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.010.gz
# Subject id: co2a0000365  Trial No:  10
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_10.csv
# It will take 12.170000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.008.gz
# Subject id: co2a0000365  Trial No:  8
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_8.csv
# It will take 11.370000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.004.gz
# Subject id: co2a0000365  Trial No:  4
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_4.csv
# It will take 11.130000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.011.gz
# Subject id: co2a0000365  Trial No:  11
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_11.csv
# It will take 11.200000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.005.gz
# Subject id: co2a0000365  Trial No:  5
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_5.csv
# It will take 10.130000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.012.gz
# Subject id: co2a0000365  Trial No:  12
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_12.csv
# It will take 10.530000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.009.gz
# Subject id: co2a0000365  Trial No:  9
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_9.csv
# It will take 9.410000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.039.gz
# Subject id: co2a0000365  Trial No:  39
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_39.csv
# It will take 9.210000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.015.gz
# Subject id: co2a0000365  Trial No:  15
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_15.csv
# It will take 9.010000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.022.gz
# Subject id: co2a0000365  Trial No:  22
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_22.csv
# It will take 8.280000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.031.gz
# Subject id: co2a0000365  Trial No:  31
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_31.csv
# It will take 7.870000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.023.gz
# Subject id: co2a0000365  Trial No:  23
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_23.csv
# It will take 7.410000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.029.gz
# Subject id: co2a0000365  Trial No:  29
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_29.csv
# It will take 6.990000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.026.gz
# Subject id: co2a0000365  Trial No:  26
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_26.csv
# It will take 6.650000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.045.gz
# Subject id: co2a0000365  Trial No:  45
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_45.csv
# It will take 6.400000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.020.gz
# Subject id: co2a0000365  Trial No:  20
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_20.csv
# It will take 5.640000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.035.gz
# Subject id: co2a0000365  Trial No:  35
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_35.csv
# It will take 5.220000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.037.gz
# Subject id: co2a0000365  Trial No:  37
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_37.csv
# It will take 4.840000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.018.gz
# Subject id: co2a0000365  Trial No:  18
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_18.csv
# It will take 4.570000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.047.gz
# Subject id: co2a0000365  Trial No:  47
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_47.csv
# It will take 3.980000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.033.gz
# Subject id: co2a0000365  Trial No:  33
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_33.csv
# It will take 3.720000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.016.gz
# Subject id: co2a0000365  Trial No:  16
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_16.csv
# It will take 3.130000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.043.gz
# Subject id: co2a0000365  Trial No:  43
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_43.csv
# It will take 2.650000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.041.gz
# Subject id: co2a0000365  Trial No:  41
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_41.csv
# It will take 2.200000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.055.gz
# Subject id: co2a0000365  Trial No:  55
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_55.csv
# It will take 1.730000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.051.gz
# Subject id: co2a0000365  Trial No:  51
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_51.csv
# It will take 1.300000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.049.gz
# Subject id: co2a0000365  Trial No:  49
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_49.csv
# It will take 0.870000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.061.gz
# Subject id: co2a0000365  Trial No:  61
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_61.csv
# It will take 0.440000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.071.gz
# Subject id: co2a0000365  Trial No:  71
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_71.csv
# It will take 0.000000 mins more for this subject!
# -------------------------------------------------------------------------------
# All files extracted and saved.
# ###########################################################
# ##########################################################
# Beginning extraction of subject  SMNI_CMI_TRAIN/co2a0000368/
# There are  30 trials under this subject
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.004.gz
# Subject id: co2a0000368  Trial No:  4
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_4.csv
# It will take 12.030000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.002.gz
# Subject id: co2a0000368  Trial No:  2
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_2.csv
# It will take 12.060000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.012.gz
# Subject id: co2a0000368  Trial No:  12
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_12.csv
# It will take 11.840000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.008.gz
# Subject id: co2a0000368  Trial No:  8
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_8.csv
# It will take 10.880000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.000.gz
# Subject id: co2a0000368  Trial No:  0
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_0.csv
# It will take 10.460000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.006.gz
# Subject id: co2a0000368  Trial No:  6
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_6.csv
# It will take 10.030000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.010.gz
# Subject id: co2a0000368  Trial No:  10
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_10.csv
# It will take 10.050000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.019.gz
# Subject id: co2a0000368  Trial No:  19
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_19.csv
# It will take 9.700000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.014.gz
# Subject id: co2a0000368  Trial No:  14
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_14.csv
# It will take 9.320000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.031.gz
# Subject id: co2a0000368  Trial No:  31
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_31.csv
# It will take 9.230000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.029.gz
# Subject id: co2a0000368  Trial No:  29
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_29.csv
# It will take 8.380000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.033.gz
# Subject id: co2a0000368  Trial No:  33
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_33.csv
# It will take 8.400000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.005.gz
# Subject id: co2a0000368  Trial No:  5
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_5.csv
# It will take 7.570000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.007.gz
# Subject id: co2a0000368  Trial No:  7
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_7.csv
# It will take 7.300000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.016.gz
# Subject id: co2a0000368  Trial No:  16
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_16.csv
# It will take 6.730000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.018.gz
# Subject id: co2a0000368  Trial No:  18
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_18.csv
# It will take 6.450000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.015.gz
# Subject id: co2a0000368  Trial No:  15
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_15.csv
# It will take 5.740000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.035.gz
# Subject id: co2a0000368  Trial No:  35
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_35.csv
# It will take 5.310000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.013.gz
# Subject id: co2a0000368  Trial No:  13
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_13.csv
# It will take 4.920000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.001.gz
# Subject id: co2a0000368  Trial No:  1
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_1.csv
# It will take 4.580000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.003.gz
# Subject id: co2a0000368  Trial No:  3
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_3.csv
# It will take 3.760000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.027.gz
# Subject id: co2a0000368  Trial No:  27
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_27.csv
# It will take 3.470000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.009.gz
# Subject id: co2a0000368  Trial No:  9
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_9.csv
# It will take 2.960000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.047.gz
# Subject id: co2a0000368  Trial No:  47
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_47.csv
# It will take 2.600000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.037.gz
# Subject id: co2a0000368  Trial No:  37
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_37.csv
# It will take 2.360000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.041.gz
# Subject id: co2a0000368  Trial No:  41
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_41.csv
# It will take 1.800000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.051.gz
# Subject id: co2a0000368  Trial No:  51
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_51.csv
# It will take 1.310000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.011.gz
# Subject id: co2a0000368  Trial No:  11
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_11.csv
# It will take 0.870000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.065.gz
# Subject id: co2a0000368  Trial No:  65
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_65.csv
# It will take 0.440000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.071.gz
# Subject id: co2a0000368  Trial No:  71
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_71.csv
# It will take 0.000000 mins more for this subject!
# -------------------------------------------------------------------------------
# All files extracted and saved.
# ###########################################################
# ##########################################################
# Beginning extraction of subject  SMNI_CMI_TRAIN/co2a0000369/
# There are  30 trials under this subject
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.000.gz
# Subject id: co2a0000369  Trial No:  0
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_0.csv
# It will take 12.060000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.004.gz
# Subject id: co2a0000369  Trial No:  4
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_4.csv
# It will take 12.170000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.018.gz
# Subject id: co2a0000369  Trial No:  18
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_18.csv
# It will take 11.700000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.014.gz
# Subject id: co2a0000369  Trial No:  14
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_14.csv
# It will take 11.800000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.010.gz
# Subject id: co2a0000369  Trial No:  10
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_10.csv
# It will take 11.310000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.006.gz
# Subject id: co2a0000369  Trial No:  6
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_6.csv
# It will take 10.080000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.008.gz
# Subject id: co2a0000369  Trial No:  8
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_8.csv
# It will take 10.330000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.012.gz
# Subject id: co2a0000369  Trial No:  12
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_12.csv
# It will take 9.570000 mins more for this subject!
# -------------------------------------------------------------------------------
# ...
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.003.gz
# Subject id: co2c0000346  Trial No:  3
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_3.csv
# It will take 0.830000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.011.gz
# Subject id: co2c0000346  Trial No:  11
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_11.csv
# It will take 0.430000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.047.gz
# Subject id: co2c0000346  Trial No:  47
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_47.csv
# It will take 0.000000 mins more for this subject!
# -------------------------------------------------------------------------------
# All files extracted and saved.
# ###########################################################
# ##########################################################
# Beginning extraction of subject  SMNI_CMI_TRAIN/co2c0000347/
# There are  30 trials under this subject
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.022.gz
# Subject id: co2c0000347  Trial No:  22
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_22.csv
# It will take 12.960000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.008.gz
# Subject id: co2c0000347  Trial No:  8
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_8.csv
# It will take 11.710000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.032.gz
# Subject id: co2c0000347  Trial No:  32
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_32.csv
# It will take 11.640000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.030.gz
# Subject id: co2c0000347  Trial No:  30
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_30.csv
# It will take 11.290000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.014.gz
# Subject id: co2c0000347  Trial No:  14
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_14.csv
# It will take 10.810000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.000.gz
# Subject id: co2c0000347  Trial No:  0
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_0.csv
# It will take 9.960000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.001.gz
# Subject id: co2c0000347  Trial No:  1
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_1.csv
# It will take 9.580000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.018.gz
# Subject id: co2c0000347  Trial No:  18
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_18.csv
# It will take 9.540000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.024.gz
# Subject id: co2c0000347  Trial No:  24
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_24.csv
# It will take 9.070000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.026.gz
# Subject id: co2c0000347  Trial No:  26
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_26.csv
# It will take 8.980000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.002.gz
# Subject id: co2c0000347  Trial No:  2
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_2.csv
# It will take 7.910000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.031.gz
# Subject id: co2c0000347  Trial No:  31
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_31.csv
# It will take 7.890000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.005.gz
# Subject id: co2c0000347  Trial No:  5
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_5.csv
# It will take 7.190000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.029.gz
# Subject id: co2c0000347  Trial No:  29
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_29.csv
# It will take 7.010000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.007.gz
# Subject id: co2c0000347  Trial No:  7
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_7.csv
# It will take 6.270000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.049.gz
# Subject id: co2c0000347  Trial No:  49
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_49.csv
# It will take 6.110000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.019.gz
# Subject id: co2c0000347  Trial No:  19
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_19.csv
# It will take 5.640000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.047.gz
# Subject id: co2c0000347  Trial No:  47
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_47.csv
# It will take 5.250000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.065.gz
# Subject id: co2c0000347  Trial No:  65
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_65.csv
# It will take 4.810000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.057.gz
# Subject id: co2c0000347  Trial No:  57
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_57.csv
# It will take 4.390000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.071.gz
# Subject id: co2c0000347  Trial No:  71
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_71.csv
# It will take 4.060000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.055.gz
# Subject id: co2c0000347  Trial No:  55
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_55.csv
# It will take 3.520000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.059.gz
# Subject id: co2c0000347  Trial No:  59
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_59.csv
# It will take 3.060000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.053.gz
# Subject id: co2c0000347  Trial No:  53
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_53.csv
# It will take 2.610000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.061.gz
# Subject id: co2c0000347  Trial No:  61
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_61.csv
# It will take 2.200000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.023.gz
# Subject id: co2c0000347  Trial No:  23
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_23.csv
# It will take 1.730000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.075.gz
# Subject id: co2c0000347  Trial No:  75
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_75.csv
# It will take 1.300000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.081.gz
# Subject id: co2c0000347  Trial No:  81
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_81.csv
# It will take 0.870000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.077.gz
# Subject id: co2c0000347  Trial No:  77
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_77.csv
# It will take 0.430000 mins more for this subject!
# -------------------------------------------------------------------------------
# Beginning extraction of file:  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.079.gz
# Subject id: co2c0000347  Trial No:  79
# There are  16384  rows and  7  columns in this dataframe object
# CSV file successully saved as  /content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_79.csv
# It will take 0.000000 mins more for this subject!
# -------------------------------------------------------------------------------
# All files extracted and saved.
# ###########################################################

# %% [markdown]
# ## Functions for Concatenating Data for Single Subject

# %%
def concat_df(sorted_files,verbosity):
    
    """
        Function to join together trial files belonging to a single subject
        and returns a dataframe object containing all the trials."""
    
    result = pd.DataFrame()
    for sorted_file in sorted_files:
        df = pd.read_csv(sorted_file, delim_whitespace=False, sep='\t', 
                         index_col = False)
        chan_names = df.chan_name.unique()    
        if verbosity >1:
            print('File loaded {}'.format((sorted_file.split('/')[5])))
        trial_voltage = []
        norm_voltage = []
        Norm_voltage =[]
        for chan in chan_names:
            #norm_voltage = []
            voltages = []  
            chan_df = pd.DataFrame()
            chan_df = df.loc[df['chan_name'] == chan]
            voltages = chan_df[['voltage']].values
            max_volt = max(voltages)
            min_volt = min(voltages)
            voltages = [x/abs(max_volt) if (x>0) else x for x in voltages]            #rescale voltage values to range [-1,1]
            voltages = [x/abs(min_volt) if (x<0) else x for x in voltages]
            norm_voltage.extend(voltages)
            Norm_voltage = np.asarray(norm_voltage)
        trial_voltage = np.concatenate(Norm_voltage, axis=0)
        df['norm_voltage'] = pd.Series(trial_voltage, index=df.index)
        result = result.append(df, ignore_index=True)
            
    return result

# %%
def sort_files(dir_path,sub_id):
    """
        Function sorts trial files under a subject folder in ascending order of trial number.
    """
    os.chdir('/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/')
    files = [file for file in glob.glob(dir_path+sub_id+'_[0-9]*.csv') if file]
    print(files)
    # sorting assumes that the file directory structure for a single trial file is of the format
    # '/home/user/eeg_data/eeg_csv/co2a0000372_107.csv'. If not change the position
    # and character used in the following line.
    sorted_files = sorted(files, key=lambda x: int((x.split('.')[0]).split('_')[6]))
    
    return sorted_files

# %%
from pathlib import Path
import os.path
def create_SubCSV(sub_files):
    """
        This function calls the concat_df function and joins together indivdual trial files
        of the subject if the file does not exist. The dataframe object is written to disk as
        a pickle object.
    """
    
    
    out_dir = eeg_data

    for subject in sub_files:
        print(subject)
        if(subject[0]!='c'):
          continue
        outname = subject+'_full.pkl' 
        # file = Path(out_dir+outname)
        # try:
        #     file_path = file.resolve()
        #     print('File exists '+outname+'. Continue.')
                       
        # except FileNotFoundError:
        print('File does not exists '+outname+'. Begin.')
        sorted_files = sort_files(out_dir,subject)
        sub_df = concat_df(sorted_files,5)
        sub_df.to_pickle(outname)

# %% [markdown]
# ## Create Subject files and store as pickle files
# Create full subject files and store them to disk as pickle files for easy and fast access later.

# %%
main_dir = "/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/"
eeg_data = os.path.join(main_dir+'SMNI_CMI_TRAIN/')  # unzipped subjects data file location

subject_files = os.listdir(eeg_data) # list all the subject folders
os.chdir(eeg_data)
alcoholics = [file.replace('/', '') for file in glob.glob('co?a*/')]
controls = [file.replace('/', '') for file in glob.glob('co?c*/')]
create_SubCSV(controls)
create_SubCSV(alcoholics)
# Out:
# co2c0000338
# File does not exists co2c0000338_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_51.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000338_47.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000337
# File does not exists co2c0000337_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_26.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_30.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_24.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_28.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_32.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_34.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_36.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_51.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_55.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_43.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_65.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_71.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_87.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_83.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_67.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_89.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_73.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000337_53.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000339
# File does not exists co2c0000339_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_20.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_36.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_30.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_22.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_34.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_53.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_43.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_55.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_39.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_49.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_75.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_71.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_65.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_79.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000339_77.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000340
# File does not exists co2c0000340_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_43.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_53.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_49.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_65.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_63.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_83.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_57.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_75.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_107.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_79.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_77.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000340_97.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000341
# File does not exists co2c0000341_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_22.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_20.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_51.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_65.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000341_61.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000342
# File does not exists co2c0000342_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_20.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000342_55.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000344
# File does not exists co2c0000344_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_32.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_26.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_28.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_22.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_24.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_30.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_39.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_45.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_49.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_43.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_65.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_51.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_53.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_71.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_55.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000344_75.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000345
# File does not exists co2c0000345_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000345_25.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000346
# File does not exists co2c0000346_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_24.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_26.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_28.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000346_47.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2c0000347
# File does not exists co2c0000347_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_22.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_32.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_30.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_24.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_26.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_49.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_65.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_57.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_71.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_55.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_59.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_53.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_61.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_75.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_81.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_77.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2c0000347_79.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000364
# File does not exists co2a0000364_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_28.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_24.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_22.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_20.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_39.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_45.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_59.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_57.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_49.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_43.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_61.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_55.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000364_25.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000365
# File does not exists co2a0000365_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_39.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_22.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_26.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_45.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_20.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_43.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_55.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_51.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_49.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_61.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000365_71.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000368
# File does not exists co2a0000368_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_51.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_65.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000368_71.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000369
# File does not exists co2a0000369_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_39.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000369_27.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000370
# File does not exists co2a0000370_full.pkl. Begin.
# ...
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000372
# File does not exists co2a0000372_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000372_37.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000375
# File does not exists co2a0000375_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_22.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_20.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_9.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_7.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000375_29.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000377
# File does not exists co2a0000377_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_30.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_32.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_45.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_43.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_34.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_38.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_36.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_39.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_71.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_49.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_55.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_61.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_51.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000377_65.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# co2a0000378
# File does not exists co2a0000378_full.pkl. Begin.
# ['/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_8.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_10.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_6.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_0.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_12.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_2.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_4.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_19.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_21.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_13.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_5.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_14.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_1.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_29.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_15.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_16.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_18.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_23.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_37.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_47.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_3.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_31.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_41.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_17.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_35.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_25.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_27.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_33.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_11.csv', '/content/drive/My Drive/SMNI_CMI_TRAIN_unzipped/SMNI_CMI_TRAIN/co2a0000378_51.csv']
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN
# File loaded SMNI_CMI_TRAIN

# %%
print("Number of alcoholics = {} and controls = {}".format(len(alcoholics),len(controls)))
# Out:
# Number of alcoholics = 10 and controls = 10
